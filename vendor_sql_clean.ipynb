# %% [markdown]
# #Business Problem

# %% [markdown]
# Effective inventory and sales management are critical for optimizing profitability in the retail and wholesale industry. Companies need to ensure that they are not incurring losses due to inefficient pricing, poor inventory turnover, or vendor dependency. The goal of this analysis is to:
#
# Identify underperforming brands that require promotional or pricing adjustments.
# Determine top vendors contributing to sales and gross profit.
# Analyze the impact of bulk purchasing on unit costs.
# Assess inventory turnover to reduce holding costs and improve efficiency.
# Investigate the profitability variance between high-performing and low-performing vendors.

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import mysql.connector

conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3305,    
    user="root",
    password="vinay",
    database="inventroy"
)


pd.read_sql( "show tables", conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\903907392.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql( "show tables", conn)
#   Tables_in_inventroy
# 0     begin_inventory
# 1       end_inventory
# 2     purchase_prices
# 3           purchases
# 4               sales
# 5      vendor_invoice

# %%
print("*** begin_inventory ***")
begin_inventory=pd.read_sql( "select * from begin_inventory ", conn)
begin_inventory
# Out:
# *** begin_inventory ***
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\1553017695.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   begin_inventory=pd.read_sql( "select * from begin_inventory ", conn)
#             InventoryId  Store          City  Brand  \
# 0     1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1     1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2     1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3     1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4     1_HARDERSFIELD_72      1  HARDERSFIELD     72
# ...                 ...    ...           ...    ...
# 4662    2_ASHBORNE_6857      2      ASHBORNE   6857
# 4663    2_ASHBORNE_6859      2      ASHBORNE   6859
# 4664    2_ASHBORNE_6861      2      ASHBORNE   6861
# 4665    2_ASHBORNE_6864      2      ASHBORNE   6864
# ...

# %%
print("*** end_inventory ***")
end_inventory=pd.read_sql( "select * from end_inventory ", conn)
end_inventory
# Out:
# *** end_inventory ***
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\2141759304.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   end_inventory=pd.read_sql( "select * from end_inventory ", conn)
#                InventoryId  Store          City  Brand  \
# 0        1_HARDERSFIELD_58      2  HARDERSFIELD     58
# 1          2_ASHBORNE_6876      2  HARDERSFIELD     58
# 2        1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3        1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 4        1_HARDERSFIELD_63      1  HARDERSFIELD     63
# ...                    ...    ...           ...    ...
# 5028  1_HARDERSFIELD_23866      4    EANVERNESS   3682
# 5029     4_EANVERNESS_3683      4    EANVERNESS   3683
# 5030  1_HARDERSFIELD_23886      4    EANVERNESS   3683
# 5031     4_EANVERNESS_3684      4    EANVERNESS   3684
# ...

# %%
print("*** purchase_prices ***")
purchase_prices=pd.read_sql( "select * from purchase_prices ", conn)
purchase_prices
# Out:
# *** purchase_prices ***
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\1566103149.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   purchase_prices=pd.read_sql( "select * from purchase_prices ", conn)
#       Brand                  Description   Price    Size  Volume  \
# 0        58  Gekkeikan Black & Gold Sake   12.99   750mL     750
# 1        62     Herradura Silver Tequila   36.99   750mL     750
# 2        63   Herradura Reposado Tequila   38.99   750mL     750
# 3        72         No. 3 London Dry Gin   34.99   750mL     750
# 4        75    Three Olives Tomato Vodka   14.99   750mL     750
# ...     ...                          ...     ...     ...     ...
# 1071   4528        Remy Martin XO Cognac  139.99   750mL     750
# 1072   4550              E & J XO Brandy   12.99   750mL     750
# ...

# %%
print("*** purchases ***")
purchases=pd.read_sql( "select * from purchases ", conn)
purchases
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\135207974.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   purchases=pd.read_sql( "select * from purchases ", conn)
# *** purchases ***
#                  InventoryId  Store  Brand                   Description  \
# 0          69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno
# 1           30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide
# 2          34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced
# 3        1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide
# 4          76_DONCASTER_2034     76   2034     Glendalough Double Barrel
# ...                      ...    ...    ...                           ...
# 48935  72_HARDERSFIELD_46830     72  46830         Pacific Rim Sweet Rsl
# ...

# %%
print("*** sales ***")
sales=pd.read_sql( "select * from sales ", conn)
sales
# Out:
# *** sales ***
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\256281283.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sales=pd.read_sql( "select * from sales ", conn)
#                InventoryId  Store  Brand                 Description  \
# 0      1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 1      1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 2      1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 3      1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 4      1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack
# ...                    ...    ...    ...                         ...
# 5672  1_HARDERSFIELD_27644      1  27644             Cline Znfdl Cal
# 5673  1_HARDERSFIELD_27644      1  27644             Cline Znfdl Cal
# ...

# %%
print("*** vendor_invoice ***")
vendor_invoice=pd.read_sql( "select * from vendor_invoice ", conn)
vendor_invoice
# Out:
# *** vendor_invoice ***
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\3610228280.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   vendor_invoice=pd.read_sql( "select * from vendor_invoice ", conn)
#      VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0            1189  BULLY BOY DISTILLERS         2024-01-09      8171
# 1            1273  CALEDONIA SPIRITS INC        2024-01-06      8172
# 2            4380  CHARLES JACQUIN ET CIE INC   2024-01-06      8153
# 3            4679  CONSTELLATION BRANDS INC     2024-01-11      8108
# 4            9744  FREDERICK WILDMAN & SONS     2024-01-06      8176
# ..            ...                          ...         ...       ...
# 726          9622  WEIN BAUER INC               2024-04-11      9447
# ...

# %% [markdown]
# analyzing from a specific vendor

# %%
pd.read_sql( "select * from vendor_invoice where VendorNumber = 1189 ", conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\4123491591.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql( "select * from vendor_invoice where VendorNumber = 1189 ", conn)
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0          1189  BULLY BOY DISTILLERS         2024-01-09      8171
# 1          1189  BULLY BOY DISTILLERS         2024-02-02      8518
# 2          1189  BULLY BOY DISTILLERS         2024-02-10      8619
# 3          1189  BULLY BOY DISTILLERS         2024-03-22      9257
#
#        PODate     PayDate  Quantity  Dollars  Freight Approval
# 0  2023-12-24  2024-02-04         6   132.30     5.29
# 1  2024-01-18  2024-03-08        17   374.85     1.99
# 2  2024-01-25  2024-03-17        12   264.60     1.30
# 3         750  2024-04-24         9   926.10     5.00

# %%
pd.read_sql( "select * from sales where VendorNo= 1189 ", conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\2958665249.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql( "select * from sales where VendorNo= 1189 ", conn)
#            InventoryId  Store  Brand                 Description   Size  \
# 0  1_HARDERSFIELD_2130      1   2130  Bully Boy American Whiskey  750mL
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         29.99       29.99  2024-01-31   750.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       0.79      1189  BULLY BOY DISTILLERS

# %%
pd.read_sql( "select * from purchases where VendorNumber= 1189 ", conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\3114412832.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql( "select * from purchases where VendorNumber= 1189 ", conn)
#          InventoryId  Store  Brand                 Description   Size  \
# 0  38_GOULCREST_2130     38   2130  Bully Boy American Whiskey  750mL
# 1  50_MOUNTMEND_2130     50   2130  Bully Boy American Whiskey  750mL
# 2  69_MOUNTMEND_2130     69   2130  Bully Boy American Whiskey  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          1189  BULLY BOY DISTILLERS             8171  2023-12-24
# 1          1189  BULLY BOY DISTILLERS             8220  2023-12-28
# 2          1189  BULLY BOY DISTILLERS             8220  2023-12-28
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %% [markdown]
# analyzing relation between InventoryId and VendorName

# %%
purchases.groupby(["PurchasePrice","Brand","InventoryId","VendorName"])[["Quantity","Dollars"]].sum()
# Out:
#                                                                      Quantity  \
# PurchasePrice Brand InventoryId         VendorName
# 0.62          5877  19_WINTERVALE_5877  SAZERAC CO INC                     12
#                     1_HARDERSFIELD_5877 SAZERAC CO INC                    120
#                     5_SUTTON_5877       SAZERAC CO INC                      9
#                     74_PAENTMARWY_5877  SAZERAC CO INC                    120
#                     75_BARNCOMBE_5877   SAZERAC CO INC                    114
# ...                                                                       ...
# 240.59        2748  38_GOULCREST_2748   DIAGEO NORTH AMERICA INC            3
#                     67_EANVERNESS_2748  DIAGEO NORTH AMERICA INC            3
#                     6_GOULCREST_2748    DIAGEO NORTH AMERICA INC            3
#                     9_BLACKPOOL_2748    DIAGEO NORTH AMERICA INC            3
# ...

# %%
sales.groupby(["Brand","InventoryId","VendorName"])[["SalesDollars","SalesQuantity"]].sum()
# Out:
#                                                         SalesDollars  \
# Brand InventoryId          VendorName
# 115   1_HARDERSFIELD_115   MOET HENNESSY USA INC              335.88
# 120   1_HARDERSFIELD_120   MCCORMICK DISTILLING CO             27.98
# 126   1_HARDERSFIELD_126   BACARDI USA INC                    692.79
# 171   1_HARDERSFIELD_171   BROWN-FORMAN CORP                  699.86
# 175   1_HARDERSFIELD_175   PROXIMO SPIRITS INC.                83.98
# ...                                                              ...
# 27512 1_HARDERSFIELD_27512 VINEYARD BRANDS INC                 66.97
# 27514 1_HARDERSFIELD_27514 CONSTELLATION BRANDS INC            39.98
# 27567 1_HARDERSFIELD_27567 SOUTHERN WINE & SPIRITS NE          70.95
# 27596 1_HARDERSFIELD_27596 ULTRA BEVERAGE COMPANY LLP          94.68
# 27644 1_HARDERSFIELD_27644 MARTIGNETTI COMPANIES              419.58
#
#                                                         SalesQuantity
# ...

# %%
purchase_prices
# Out:
#       Brand                  Description   Price    Size  Volume  \
# 0        58  Gekkeikan Black & Gold Sake   12.99   750mL     750
# 1        62     Herradura Silver Tequila   36.99   750mL     750
# 2        63   Herradura Reposado Tequila   38.99   750mL     750
# 3        72         No. 3 London Dry Gin   34.99   750mL     750
# 4        75    Three Olives Tomato Vodka   14.99   750mL     750
# ...     ...                          ...     ...     ...     ...
# 1071   4528        Remy Martin XO Cognac  139.99   750mL     750
# 1072   4550              E & J XO Brandy   12.99   750mL     750
# 1073   4556   Austin Cocktails Vodkarita   14.99   750mL     750
# 1074   4563        Christian Bros Brandy   16.99  1750mL    1750
# 1075   4565     Christian Bros VS Brandy   10.49   750mL     750
#
#       Classification  PurchasePrice  VendorNumber                   VendorName
# 0                  1           9.28          8320  SHAW ROSS INT L IMP LTD
# ...

# %%
purchases
# Out:
#                  InventoryId  Store  Brand                   Description  \
# 0          69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno
# 1           30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide
# 2          34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced
# 3        1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide
# 4          76_DONCASTER_2034     76   2034     Glendalough Double Barrel
# ...                      ...    ...    ...                           ...
# 48935  72_HARDERSFIELD_46830     72  46830         Pacific Rim Sweet Rsl
# 48936     34_PITMERDEN_23382     34  23382     Haywood Chamizal Znfdl 09
# 48937     34_PITMERDEN_34996     34  34996   Carpineto Dogajolo Tuscan R
# 48938     66_EANVERNESS_2787     66   2787        Glenrothes Vintage Rsv
# 48939       49_GARIGILL_3763     49   3763          Patron Anejo Tequila
#
#         Size  VendorNumber                   VendorName  PONumber      PODate  \
# ...

# %%
pd.read_sql( "select * from purchases where InventoryId in ('34_PITMERDEN_34996','1_HARDERSFIELD_5255') ", conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\2215132686.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql( "select * from purchases where InventoryId in ('34_PITMERDEN_34996','1_HARDERSFIELD_5255') ", conn)
#            InventoryId  Store  Brand                   Description   Size  \
# 0  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1   34_PITMERDEN_34996     34  34996   Carpineto Dogajolo Tuscan R   1.5L
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 1          9165  ULTRA BEVERAGE COMPANY LLP       8219  2023-12-27
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0    2024-01-01  2024-01-07  2024-02-21           9.35         6     56.1
# ...

# %%
pd.read_sql( "select * from sales where InventoryId in ('34_PITMERDEN_34996','1_HARDERSFIELD_5255') ", conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\295411743.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql( "select * from sales where InventoryId in ('34_PITMERDEN_34996','1_HARDERSFIELD_5255') ", conn)
# Empty DataFrame
# Columns: [InventoryId, Store, Brand, Description, Size, SalesQuantity, SalesDollars, SalesPrice, SalesDate, Volume, Classification, ExciseTax, VendorNo, VendorName]
# Index: []

# %%
sales["InventoryId"].nunique()
# Out:
# 1070

# %%
sales["InventoryId"].shape
# Out:
# (5677,)

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
vendor_final_table=pd.read_sql( """with Freight_summary as
(select  
     VendorNumber, 
     sum(Freight) as FreightCost
     from vendor_invoice
     group by VendorNumber),
PurchaseSummary as(
select
      p.VendorNumber,
      p.VendorName,
      p.Brand,
      p.Description,
      p.PurchasePrice,
      pp.Price as Actualprice,
      pp.Volume,
      sum(p.Quantity) as totalpurchasesquantity,
      sum(p.Dollars) as totalpurchasesdollar
from purchases as p
join purchase_prices as  pp
on p.Brand = pp.Brand
where p.PurchasePrice > 0
group by p.VendorNumber,p.VendorName,p.Brand,p.Description,p.PurchasePrice,pp.Price,pp.Volume
),
salessummary as (
select 
      VendorNo,
      Brand,
      sum(SalesQuantity) as totalSalesQuantity,
      sum(SalesDollars) as totalSalesDollars,
      sum(SalesPrice) as totalSalesPrice,
      sum(ExciseTax) as totalExciseTax
from sales
group by VendorNo
)
select 
      ps.VendorNumber,
      ps.VendorName,
      ps.Brand,
      ps.Description,
      ps.PurchasePrice,
      ps.Actualprice,
      ps.Volume,
      ps.totalpurchasesquantity,
      ps.totalpurchasesdollar,
      ss.totalSalesQuantity,
      ss.totalSalesDollars,
      ss.totalSalesPrice,
      ss.totalExciseTax,
      fs.FreightCost
from PurchaseSummary as ps
left join salessummary as ss
on ps.VendorNumber = ss.VendorNo 
left join Freight_summary as fs
on ps.VendorNumber=fs.VendorNumber
order by ps.totalpurchasesdollar desc """, conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\562289306.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   vendor_final_table=pd.read_sql( """with Freight_summary as
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File C:\New folder\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# ...

# %%
vendor_final_table
# Out:
#        VendorNumber                  VendorName  Brand  \
# 0             12546     JIM BEAM BRANDS COMPANY   1476
# 1             12546     JIM BEAM BRANDS COMPANY   1476
# 2             12546     JIM BEAM BRANDS COMPANY   1476
# 3             12546     JIM BEAM BRANDS COMPANY   1476
# 4             12546     JIM BEAM BRANDS COMPANY   1476
# ...             ...                         ...    ...
# 32889          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32890          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32891          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32892          8664       STOLI GROUP,(USA) LLC   3147
# 32893          8664       STOLI GROUP,(USA) LLC   3147
#
#                         Description  PurchasePrice  Actualprice  Volume  \
# 0                 Jim Beam Traveler          16.05        21.99    1750
# 1                 Jim Beam Traveler          16.05        21.99    1750
# 2                 Jim Beam Traveler          16.05        21.99    1750
# ...

# %%
vendor_final_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32894 entries, 0 to 32893
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VendorNumber            32894 non-null  int64
#  1   VendorName              32894 non-null  object
#  2   Brand                   32894 non-null  int64
#  3   Description             32894 non-null  object
#  4   PurchasePrice           32894 non-null  float64
#  5   Actualprice             32894 non-null  float64
#  6   Volume                  32894 non-null  int64
#  7   totalpurchasesquantity  32894 non-null  float64
#  8   totalpurchasesdollar    32894 non-null  float64
#  9   totalSalesQuantity      32877 non-null  float64
#  10  totalSalesDollars       32877 non-null  float64
#  11  totalSalesPrice         32877 non-null  float64
#  12  totalExciseTax          32877 non-null  float64
#  13  FreightCost             32894 non-null  float64
# ...

# %%
vendor_final_table["VendorName"]=vendor_final_table["VendorName"].str.strip()

# %%
vendor_final_table["VendorName"]
# Out:
# 0           JIM BEAM BRANDS COMPANY
# 1           JIM BEAM BRANDS COMPANY
# 2           JIM BEAM BRANDS COMPANY
# 3           JIM BEAM BRANDS COMPANY
# 4           JIM BEAM BRANDS COMPANY
#                     ...
# 32889    ULTRA BEVERAGE COMPANY LLP
# 32890    ULTRA BEVERAGE COMPANY LLP
# 32891    ULTRA BEVERAGE COMPANY LLP
# 32892         STOLI GROUP,(USA) LLC
# 32893         STOLI GROUP,(USA) LLC
# Name: VendorName, Length: 32894, dtype: object

# %%
vendor_final_table["Description"]
# Out:
# 0                   Jim Beam Traveler
# 1                   Jim Beam Traveler
# 2                   Jim Beam Traveler
# 3                   Jim Beam Traveler
# 4                   Jim Beam Traveler
#                      ...
# 32889           Patron Silver Tequila
# 32890           Patron Silver Tequila
# 32891           Patron Silver Tequila
# 32892    Stolichnaya Chocolat Kokonut
# 32893    Stolichnaya Chocolat Kokonut
# Name: Description, Length: 32894, dtype: object

# %%
vendor_final_table["totalSalesQuantity"].mean()
# Out:
# 13.305776074459349

# %%
vendor_final_table["totalSalesDollars"].mean()
# Out:
# 221.71792073486023

# %%
vendor_final_table["totalSalesPrice"].mean()
# Out:
# 121.29483529519119

# %%
vendor_final_table["totalExciseTax"].mean()
# Out:
# 13.913562753036437

# %%
vendor_final_table
# Out:
#        VendorNumber                  VendorName  Brand  \
# 0             12546     JIM BEAM BRANDS COMPANY   1476
# 1             12546     JIM BEAM BRANDS COMPANY   1476
# 2             12546     JIM BEAM BRANDS COMPANY   1476
# 3             12546     JIM BEAM BRANDS COMPANY   1476
# 4             12546     JIM BEAM BRANDS COMPANY   1476
# ...             ...                         ...    ...
# 32889          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32890          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32891          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32892          8664       STOLI GROUP,(USA) LLC   3147
# 32893          8664       STOLI GROUP,(USA) LLC   3147
#
#                         Description  PurchasePrice  Actualprice  Volume  \
# 0                 Jim Beam Traveler          16.05        21.99    1750
# 1                 Jim Beam Traveler          16.05        21.99    1750
# 2                 Jim Beam Traveler          16.05        21.99    1750
# ...

# %%
vendor_final_table["GrossProfit"]=vendor_final_table["totalSalesDollars"]-vendor_final_table["totalpurchasesdollar"]

# %%
vendor_final_table.isnull()
# Out:
#        VendorNumber  VendorName  Brand  Description  PurchasePrice  \
# 0             False       False  False        False          False
# 1             False       False  False        False          False
# 2             False       False  False        False          False
# 3             False       False  False        False          False
# 4             False       False  False        False          False
# ...             ...         ...    ...          ...            ...
# 32889         False       False  False        False          False
# 32890         False       False  False        False          False
# 32891         False       False  False        False          False
# 32892         False       False  False        False          False
# 32893         False       False  False        False          False
#
#        Actualprice  Volume  totalpurchasesquantity  totalpurchasesdollar  \
# 0            False   False                   False                 False
# ...

# %%
vendor_final_table["ProfitMargin"]=(vendor_final_table["GrossProfit"] / vendor_final_table["totalSalesDollars"])*100

# %%
vendor_final_table["ProfitMargin"]
# Out:
# 0       -1.476119e+05
# 1       -6.782466e+04
# 2       -2.978201e+06
# 3       -3.395233e+05
# 4       -2.702235e+05
#              ...
# 32889    9.328687e+01
# 32890    8.984410e+01
# 32891    8.809675e+01
# 32892    9.936528e+01
# 32893    9.691170e+01
# Name: ProfitMargin, Length: 32894, dtype: float64

# %%
vendor_final_table["StockTurnover"]=vendor_final_table["totalSalesQuantity"]/vendor_final_table["totalpurchasesquantity"]

# %%
vendor_final_table["Salestopurchasesratio"]=vendor_final_table["totalSalesDollars"]/vendor_final_table["totalpurchasesdollar"]

# %%
vendor_final_table
# Out:
#        VendorNumber                  VendorName  Brand  \
# 0             12546     JIM BEAM BRANDS COMPANY   1476
# 1             12546     JIM BEAM BRANDS COMPANY   1476
# 2             12546     JIM BEAM BRANDS COMPANY   1476
# 3             12546     JIM BEAM BRANDS COMPANY   1476
# 4             12546     JIM BEAM BRANDS COMPANY   1476
# ...             ...                         ...    ...
# 32889          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32890          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32891          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32892          8664       STOLI GROUP,(USA) LLC   3147
# 32893          8664       STOLI GROUP,(USA) LLC   3147
#
#                         Description  PurchasePrice  Actualprice  Volume  \
# 0                 Jim Beam Traveler          16.05        21.99    1750
# 1                 Jim Beam Traveler          16.05        21.99    1750
# 2                 Jim Beam Traveler          16.05        21.99    1750
# ...

# %%
cursor=conn.cursor()

# %%
vendor_final_table.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'Actualprice', 'Volume', 'totalpurchasesquantity',
#        'totalpurchasesdollar', 'totalSalesQuantity', 'totalSalesDollars',
#        'totalSalesPrice', 'totalExciseTax', 'FreightCost', 'GrossProfit',
#        'ProfitMargin', 'StockTurnover', 'Salestopurchasesratio'],
#       dtype='object')

# %%
cursor.execute("""create table vendor_final_table(
       VendorNumber int,
       VendorName varchar(100),
       Brand int,
       Description varchar(100),
       PurchasePrice DECIMAL(10,2),
       Actualprice decimal(10,2),
       Volume float,
       totalpurchasesquantity int,
       totalpurchasesdollar decimal(15,2),
       totalSalesQuantity  int,
       totalSalesDollars  decimal(15,2),
       totalSalesPrice  decimal(15,2),
       totalExciseTax  decimal(15,2),
       FreightCost  decimal(15,2),
       GrossProfit  decimal(15,2),
       ProfitMargin  decimal(15,2),
       StockTurnover  decimal(15,2),
       Salestopurchasesratio  decimal(15,2),
       primary key(VendorNumber,Brand)
       );
       """)

# %%
pd.read_sql("select * from vendor_final_table",conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\2224007089.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from vendor_final_table",conn)
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, Description, PurchasePrice, Actualprice, Volume, totalpurchasesquantity, totalpurchasesdollar, totalSalesQuantity, totalSalesDollars, totalSalesPrice, totalExciseTax, FreightCost, GrossProfit, ProfitMargin, StockTurnover, Salestopurchasesratio]
# Index: []

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:vinay@127.0.0.1:3305/inventroy")

vendor_final_table.to_sql(
    name='vendor_final_table',
    con=engine, 
    if_exists='replace',
    index=False,
    chunksize=1000  # optional for large data
)
# Out:
# 32894

# %%
pd.read_sql("select * from vendor_final_table",conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\2224007089.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from vendor_final_table",conn)
#        VendorNumber                  VendorName  Brand  \
# 0             12546     JIM BEAM BRANDS COMPANY   1476
# 1             12546     JIM BEAM BRANDS COMPANY   1476
# 2             12546     JIM BEAM BRANDS COMPANY   1476
# 3             12546     JIM BEAM BRANDS COMPANY   1476
# 4             12546     JIM BEAM BRANDS COMPANY   1476
# ...             ...                         ...    ...
# 32889          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32890          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32891          9165  ULTRA BEVERAGE COMPANY LLP   3084
# 32892          8664       STOLI GROUP,(USA) LLC   3147
# ...
